# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
location = "dc-residential-properties/DC_Properties.csv"
df = pd.read_csv(location,low_memory=False,encoding = "ISO-8859-1")
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0  ... -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0  ... -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0  ... -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0  ... -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0  ... -77.039361       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
#df.dtypes
df[['AYB', 'PRICE']].groupby(['AYB']).mean().style.format('${0:,.0f}')
# Out:
# <style  type="text/css" >
# </style><table id="T_94b74ce2_dfbe_11e9_ad5f_505bc2ce3e16" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PRICE</th>    </tr>    <tr>        <th class="index_name level0" >AYB</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_94b74ce2_dfbe_11e9_ad5f_505bc2ce3e16level0_row0" class="row_heading level0 row0" >1754.0</th>
#                         <td id="T_94b74ce2_dfbe_11e9_ad5f_505bc2ce3e16row0_col0" class="data row0 col0" >$7,100,000</td>
#             </tr>
#             <tr>
#                         <th id="T_94b74ce2_dfbe_11e9_ad5f_505bc2ce3e16level0_row1" class="row_heading level0 row1" >1765.0</th>
#                         <td id="T_94b74ce2_dfbe_11e9_ad5f_505bc2ce3e16row1_col0" class="data row1 col0" >$1,100,000</td>
#             </tr>
#             <tr>
# ...

# %%
pd.pivot_table(df, index=['PRICE'])
# Out:
#                      AYB     BATHRM      BEDRM  BLDG_NUM  CENSUS_TRACT  \
# PRICE
# 1.0          1953.000000   1.800000   3.000000       1.0   5500.800000
# 10.0         1917.750000   1.500000   2.750000       1.0   5402.000000
# 250.0        1914.428571   2.142857   3.500000       1.0   5330.642857
# 500.0        1908.333333   2.500000   4.250000       1.0   3725.500000
# 936.0        1900.000000   2.000000   4.000000       1.0   4801.000000
# 1000.0       1935.800000   1.600000   2.200000       1.0   5383.200000
# 1377.0       1900.000000   1.000000   3.000000       1.0   4400.000000
# 2000.0       1914.000000   1.000000   1.500000       1.0   6505.000000
# 3000.0       1999.500000   2.000000   2.500000       1.0   4905.500000
# 3270.0       1950.000000   1.000000   1.000000       1.0   5301.000000
# 3523.0       1949.000000   1.000000   1.000000       1.0   9807.000000
# 3997.0       1948.000000   1.000000   3.000000       1.0   7709.000000
# ...

# %%
df['PRICE'].max()
# Out:
# 137427545.0

# %%
df.describe()
# Out:
#               BATHRM      HF_BATHRM      NUM_UNITS          ROOMS  \
# count  158957.000000  158957.000000  106696.000000  158957.000000
# mean        1.810678       0.458237       1.198039       6.187736
# std         0.976396       0.587571       0.596924       2.618165
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       1.000000       4.000000
# 50%         2.000000       0.000000       1.000000       6.000000
# 75%         2.000000       1.000000       1.000000       7.000000
# max        14.000000      11.000000       6.000000      48.000000
#
#                BEDRM            AYB       YR_RMDL            EYB  \
# count  158957.000000  158686.000000  80928.000000  158957.000000
# mean        2.732506    1941.987579   1998.243537    1963.718024
# std         1.358864      33.640234     16.575786      24.923150
# min         0.000000    1754.000000     20.000000    1800.000000
# ...

# %%
df['AYB'].value_counts()
# Out:
# 350000.0     595
# 250000.0     536
# 300000.0     523
# 450000.0     519
# 375000.0     488
# 325000.0     482
# 550000.0     459
# 275000.0     455
# 500000.0     426
# 320000.0     425
# 200000.0     422
# 425000.0     419
# 600000.0     403
# 315000.0     402
# 330000.0     396
# 650000.0     387
# 525000.0     387
# 285000.0     377
# 225000.0     376
# 265000.0     374
# 310000.0     371
# 475000.0     364
# 360000.0     364
# 260000.0     360
# 280000.0     352
# 385000.0     352
# 335000.0     352
# 220000.0     349
# 240000.0     348
# 230000.0     347
#             ...
# 168700.0       1
# 674755.0       1
# 5397500.0      1
# 168670.0       1
# 674670.0       1
# 468400.0       1
# 337325.0       1
# 1096000.0      1
# 337562.0       1
# 1350250.0      1
# 337575.0       1
# 117164.0       1
# 84461.0        1
# 468890.0       1
# 84450.0        1
# 84449.0        1
# 503850.0       1
# 337750.0       1
# 675490.0       1
# 114620.0       1
# 466250.0       1
# ...

# %%
df[['PRICE','BATHRM','HF_BATHRM','KITCHENS','FIREPLACES','ROOMS',]].groupby(df['AYB']).mean() #style.format('${0:,.0f}')
# Out:
#                PRICE    BATHRM  HF_BATHRM  KITCHENS  FIREPLACES      ROOMS
# AYB
# 1754.0  7.100000e+06  5.500000   2.000000  1.000000    8.000000  11.500000
# 1765.0  1.100000e+06  2.000000   1.000000  1.000000    1.000000   4.000000
# 1776.0  4.742500e+05  2.333333   0.666667  1.333333    2.333333   5.666667
# 1780.0  7.716667e+05  1.750000   1.000000  1.000000    0.250000   5.250000
# 1782.0           NaN  1.000000   1.000000  1.000000    4.000000   6.000000
# 1784.0           NaN  5.000000   1.000000  1.000000    6.000000  11.000000
# 1785.0           NaN  2.000000   1.000000  1.000000    5.000000   7.000000
# 1787.0           NaN  6.000000   1.000000  1.000000    1.000000  14.000000
# 1788.0           NaN  4.000000   1.000000  1.000000    5.000000   8.000000
# 1790.0  1.512167e+06  2.333333   0.333333  1.000000    1.666667   6.666667
# 1791.0           NaN  2.000000   1.000000  1.000000    5.000000   8.000000
# ...

# %%
df[df['PRICE'].notnull()&df['AYB'].notnull()]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 14              14       3          1      Warm Cool  Y        2.0      5
# 16              16       3          1      Warm Cool  Y        1.0      8
# 19              19       3          1  Hot Water Rad  Y        2.0      9
# 20              20       3          1  Hot Water Rad  Y        1.0     14
# 22              22       1          0     Forced Air  Y        1.0      6
# 23              23       2          1     Forced Air  Y        1.0      5
# ...

# %%
df.loc[(df['AYB'] == 1754 )&(df['PRICE'] >=7000000)]
# Out:
#        Unnamed: 0  BATHRM  HF_BATHRM       HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 37034       37034       7          2  Warm Cool  Y        1.0     14      8
#
#           AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 37034  1754.0   1983.0  ... -77.053515         Kalorama     029 A Kalorama
#
#        CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X         Y QUADRANT
# 37034        4100.0  004100 2004  Ward 2    2502 -77.054567  38.91786       NW
#
# [1 rows x 49 columns]

# %%
bins_years = [1700,1800,1900,2000,2100,]
group_names = [17,18,19,20]
df['CENTURY']= pd.cut(df['AYB'],bins_years,labels=group_names)
df.head()
# Out:
#         BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  \
# Number
# 0            4          0      Warm Cool  Y        2.0      8      4  1910.0
# 1            3          1      Warm Cool  Y        2.0     11      5  1898.0
# 2            3          1  Hot Water Rad  Y        2.0      9      5  1910.0
# 3            3          1  Hot Water Rad  Y        2.0      8      5  1900.0
# 4            2          1      Warm Cool  Y        1.0     11      3  1913.0
#
#         YR_RMDL   EYB  ...  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  CENSUS_TRACT  \
# Number                 ...
# 0        1988.0  1972  ...       Old City 2   040 D Old City 2        4201.0
# 1        2007.0  1972  ...       Old City 2   040 D Old City 2        4201.0
# 2        2009.0  1984  ...       Old City 2   040 D Old City 2        4201.0
# 3        2003.0  1984  ...       Old City 2   040 D Old City 2        4201.0
# 4        2012.0  1985  ...       Old City 2   040 D Old City 2        4201.0
#
# ...

# %%
df.rename(columns={'Unnamed: 0':'Number'}, inplace=True)
df.head()
# Out:
#    Number  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0       0       4          0      Warm Cool  Y        2.0      8      4
# 1       1       3          1      Warm Cool  Y        2.0     11      5
# 2       2       3          1  Hot Water Rad  Y        2.0      9      5
# 3       3       3          1  Hot Water Rad  Y        2.0      8      5
# 4       4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL  ...  ASSESSMENT_NBHD  ASSESSMENT_SUBNBHD CENSUS_TRACT  \
# 0  1910.0   1988.0  ...       Old City 2    040 D Old City 2       4201.0
# 1  1898.0   2007.0  ...       Old City 2    040 D Old City 2       4201.0
# 2  1910.0   2009.0  ...       Old City 2    040 D Old City 2       4201.0
# 3  1900.0   2003.0  ...       Old City 2    040 D Old City 2       4201.0
# 4  1913.0   2012.0  ...       Old City 2    040 D Old City 2       4201.0
#
#    CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT CENTURY
# ...

# %%
df.set_index('Number', inplace=True)
df.head()
# Out:
#         BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  \
# Number
# 0            4          0      Warm Cool  Y        2.0      8      4  1910.0
# 1            3          1      Warm Cool  Y        2.0     11      5  1898.0
# 2            3          1  Hot Water Rad  Y        2.0      9      5  1910.0
# 3            3          1  Hot Water Rad  Y        2.0      8      5  1900.0
# 4            2          1      Warm Cool  Y        1.0     11      3  1913.0
#
#         YR_RMDL   EYB  ...  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  CENSUS_TRACT  \
# Number                 ...
# 0        1988.0  1972  ...       Old City 2   040 D Old City 2        4201.0
# 1        2007.0  1972  ...       Old City 2   040 D Old City 2        4201.0
# 2        2009.0  1984  ...       Old City 2   040 D Old City 2        4201.0
# 3        2003.0  1984  ...       Old City 2   040 D Old City 2        4201.0
# 4        2012.0  1985  ...       Old City 2   040 D Old City 2        4201.0
#
# ...

# %%
df[df['AYB'].notnull()&df['FIREPLACES'].notnull()]
# Out:
#         BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  \
# Number
# 0            4          0      Warm Cool  Y        2.0      8      4  1910.0
# 1            3          1      Warm Cool  Y        2.0     11      5  1898.0
# 2            3          1  Hot Water Rad  Y        2.0      9      5  1910.0
# 3            3          1  Hot Water Rad  Y        2.0      8      5  1900.0
# 4            2          1      Warm Cool  Y        1.0     11      3  1913.0
# 5            3          2  Hot Water Rad  Y        1.0     10      5  1913.0
# 6            1          0      Warm Cool  Y        2.0      5      2  1917.0
# 7            3          1  Hot Water Rad  Y        2.0      8      4  1906.0
# 8            3          1      Warm Cool  Y        2.0      7      3  1908.0
# 9            1          1  Hot Water Rad  Y        1.0      6      2  1908.0
# 10           3          0     Forced Air  N        3.0     12      5  1890.0
# ...

# %%
df_no_missing=df.dropna()
df_no_missing
# Out:
# Empty DataFrame
# Columns: [BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT, CENTURY]
# Index: []
#
# [0 rows x 49 columns]

# %%
pd.value_counts(df['CENTURY'])
# Out:
# 19    126204
# 20     17646
# 18     14763
# 17        73
# Name: CENTURY, dtype: int64

# %%
df.groupby('CENTURY')['PRICE'].mean()
# Out:
# CENTURY
# 17    1.250929e+06
# 18    7.179384e+05
# 19    1.030175e+06
# 20    5.826331e+05
# Name: PRICE, dtype: float64

# %%
#df.groupby(['CENTURY','ROOMS'])['FIREPLACES'].mean()
df.groupby(['CENTURY'])['ROOMS','FIREPLACES'].mean()
# Out:
#             ROOMS  FIREPLACES
# CENTURY
# 17       7.013699    2.191781
# 18       6.522861    0.969451
# 19       6.311409    2.820283
# 20       5.007197    0.393914

# %%
sns.lmplot(x='FIREPLACES', y='ROOMS', data=copydf,
           fit_reg=False,
           hue='CENTURY')

# %%
#calculate and remove outliers

meanfire = df['FIREPLACES'].mean()
stdfire = df['FIREPLACES'].std()
toprange = meanfire + stdfire * 1.96
botrange = meanfire - stdfire * 1.96
print(botrange,toprange)
copydf = df.copy() #to not mess up the original df
copydf = copydf.drop(copydf[copydf['FIREPLACES'] > toprange].index)
copydf = copydf.drop(copydf[copydf['FIREPLACES'] < botrange].index)

copydf.head()
# Out:
# -1442.7246923517655 1447.474039659528
#         BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  \
# Number
# 0            4          0      Warm Cool  Y        2.0      8      4  1910.0
# 1            3          1      Warm Cool  Y        2.0     11      5  1898.0
# 2            3          1  Hot Water Rad  Y        2.0      9      5  1910.0
# 3            3          1  Hot Water Rad  Y        2.0      8      5  1900.0
# 4            2          1      Warm Cool  Y        1.0     11      3  1913.0
#
#         YR_RMDL   EYB  ...  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  CENSUS_TRACT  \
# Number                 ...
# 0        1988.0  1972  ...       Old City 2   040 D Old City 2        4201.0
# 1        2007.0  1972  ...       Old City 2   040 D Old City 2        4201.0
# 2        2009.0  1984  ...       Old City 2   040 D Old City 2        4201.0
# 3        2003.0  1984  ...       Old City 2   040 D Old City 2        4201.0
# ...

# %%
copydf = df.copy()
copydf = copydf.drop(copydf[copydf['FIREPLACES'] > copydf['ROOMS']].index)
#copydf = copydf.drop(copydf[copydf['FIREPLACES'] < botrange].index)

copydf
# Out:
#         BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  \
# Number
# 0            4          0      Warm Cool  Y        2.0      8      4  1910.0
# 1            3          1      Warm Cool  Y        2.0     11      5  1898.0
# 2            3          1  Hot Water Rad  Y        2.0      9      5  1910.0
# 3            3          1  Hot Water Rad  Y        2.0      8      5  1900.0
# 4            2          1      Warm Cool  Y        1.0     11      3  1913.0
# 5            3          2  Hot Water Rad  Y        1.0     10      5  1913.0
# 6            1          0      Warm Cool  Y        2.0      5      2  1917.0
# 7            3          1  Hot Water Rad  Y        2.0      8      4  1906.0
# 8            3          1      Warm Cool  Y        2.0      7      3  1908.0
# 9            1          1  Hot Water Rad  Y        1.0      6      2  1908.0
# 10           3          0     Forced Air  N        3.0     12      5  1890.0
# ...

# %%
q1 = df['FIREPLACES'].quantile(.25)
q3 = df['FIREPLACES'].quantile(.75)
iqr = q3-q1
toprange = q3 + iqr * 1.5
botrange = q1 - iqr * 1.5

copydf = df.copy()
copydf = copydf.drop(copydf[copydf['FIREPLACES'] > toprange].index)
copydf = copydf.drop(copydf[copydf['FIREPLACES'] < botrange].index)

copydf
# Out:
#         BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  \
# Number
# 4            2          1      Warm Cool  Y        1.0     11      3  1913.0
# 6            1          0      Warm Cool  Y        2.0      5      2  1917.0
# 7            3          1  Hot Water Rad  Y        2.0      8      4  1906.0
# 8            3          1      Warm Cool  Y        2.0      7      3  1908.0
# 9            1          1  Hot Water Rad  Y        1.0      6      2  1908.0
# 10           3          0     Forced Air  N        3.0     12      5  1890.0
# 11           5          0  Hot Water Rad  Y        3.0     16      6  1905.0
# 13           2          0      Warm Cool  Y        2.0     11      5  1885.0
# 14           3          1      Warm Cool  Y        2.0      5      3  1917.0
# 15           2          1      Warm Cool  Y        2.0      9      4  1908.0
# 16           3          1      Warm Cool  Y        1.0      8      3  1908.0
# ...

# %%
sns.boxplot(data=copydf)

# %%
df.loc[df['FIREPLACES'] >= 100000]['FIREPLACES']
# Out:
# Number
# 134928    293920
# Name: FIREPLACES, dtype: int64

# %%
df.drop(134928, axis=0).count()
# Out:
# BATHRM                158956
# HF_BATHRM             158956
# HEAT                  158956
# AC                    158956
# NUM_UNITS             106696
# ROOMS                 158956
# BEDRM                 158956
# AYB                   158685
# YR_RMDL                80927
# EYB                   158956
# STORIES               106652
# SALEDATE              132186
# PRICE                  98215
# QUALIFIED             158956
# SALE_NUM              158956
# GBA                   106696
# BLDG_NUM              158956
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158956
# USECODE               158956
# LANDAREA              158956
# GIS_LAST_MOD_DTTM     158956
# SOURCE                158956
# CMPLX_NUM              52260
# LIVING_GBA             52260
# ...
